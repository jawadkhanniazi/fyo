# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.dawn.com/prayers-timings/'

# %%
r = requests.get(url)
htmlContent = r.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
#print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <!--[if lt IE 7]>  <html lang="en" class="ie ie6 lte9 lte8 lte7"> <![endif]-->
# <!--[if IE 7]>     <html lang="en" class="ie ie7 lte9 lte8 lte7"> <![endif]-->
# <!--[if IE 8]>     <html lang="en" class="ie ie8 lte9 lte8"> <![endif]-->
# <!--[if IE 9]>     <html lang="en" class="ie ie9 lte9"> <![endif]-->
# <!--[if gt IE 9]>  <html lang="en"> <![endif]-->
# <!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
# <title>Prayers Timings - DAWN.COM</title>
# <meta content="Your window to latest news, analysis and features from Pakistan, South Asia and the world." name="subject">
# <meta content="1383068068604634" property="fb:app_id">
# <meta content="86398345441" property="fb:pages"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="http://www.dawn.com/_img/social-default.jpg" property="og:image"/>
# <meta content="http://www.dawn.com/_img/social-default.jpg" name="twitter:image"/>
# <script type="application/ld+json">
#          {"@context":"http:\/\/schema.org","@type":"organization","logo":"https:\/\/www.dawn.com\/_img\/logo.png","name":"DAWN.COM","url":"https:\/\/www.dawn.com","sameAs":["https:\/\/www.facebook.com\/dawndotcom\/","https:\/\/twitter.com\/dawn_com","https:\/\/www.instagram.com\/dawn_dot_com\/",""],"potentialAction":{"@type":"SearchAction","target":"https:\/\/www.dawn.com\/search?cx=partner-pub-8258178831251847:5337004877&ie=UTF-8&q={search_term_string}","query-input":"required name=search_term_string"}}
#      </script>
# <link href="https://www.dawn.com/_css/all.20201217161110.css" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/shamedawn.20201224164809.css" media="all" rel="stylesheet"/>
# <script defer="true" src="https://code.jquery.com/jquery-3.2.1.min.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/all.20201224153011.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/admin.20201126131409.js"></script>
# <link as="style" href="https://www.dawn.com/_css/all.20201217161110.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/shamedawn.20201224164809.css" rel="preload"/>
# <link as="script" href="https://code.jquery.com/jquery-3.2.1.min.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/all.20201224153011.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/admin.20201126131409.js" rel="preload"/>
# <link href="i.dawn.com" rel="dns-prefetch preconnect"/>
# <link href="code.jquery.com" rel="dns-prefetch preconnect"/>
# <!-- - - - - - - adsense:header start - - - - - - -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script type="text/javascript">
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# googleAdsSlots = [];
# googletag.cmd.push(function() {
#
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-ASA-DESKTOP-TOP', [[728,90],[970,90],[970,250]], 'div-gpt-ad-1510380105517-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-LB-728x90-BOTTOM', [728,90], 'div-gpt-ad-1509519280329-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-MREC-DESKTOP-300x250-TOP', [[300,250],[336,280]], 'div-gpt-ad-1455520357400-3').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-FLIMSTRIP-300x600', [[300,250],[300,600],[160,600]], 'div-gpt-ad-1520840073529-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-STICKY-MOBILE-320x50', [320,50], 'div-gpt-ad-1538376752024-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-STICKY-DESKTOP-728x60', [[728,90],[728,60]], 'div-gpt-ad-1538376694503-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-ASA-MOBILE-TOP', [[320,50],[728,90],[320,100]], 'div-gpt-ad-1518611317921-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-STICKY-DESKTOP-1x1', [1,1], 'div-gpt-ad-1535620321579-0').addService(googletag.pubads()));
#     googleAdsSlots.push(googletag.defineSlot('/1029551/DAWN-STICKY-MOBILE-1x1', [1,1], 'div-gpt-ad-1542969151399-0').addService(googletag.pubads()));
#
#   googletag.pubads().set("document_language", "en");
#
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().setTargeting('site', 'www.dawn.com');
#
#   googletag.pubads().disableInitialLoad();
#   googletag.pubads().enableLazyLoad({
#                 fetchMarginPercent: 300,
#                 renderMarginPercent: 300,
#                 mobileScaling: 2.0
#             })
#   googletag.enableServices();
# });
# function render(divId) {
#     var cookieValue = "; " + document.cookie;
#     var cookieParts = cookieValue.split("; " + divId + "=");
#     if (cookieParts.pop().split(';').shift() != divId) {
#         googletag.cmd.push(function() {googletag.display(divId)});
#     } else {
#         if (divId) {
#             var adContainer = document.getElementById(divId).closest('.ad');
#             adContainer.classList.remove('block', 'sm:block');
#             adContainer.classList.add('hidden');
#         } else {
#             console.log('Error: Ad not found divid: ' + divId);
#         }
#     }
# }
# </script>
# <!-- - - - - - - adsense:header end - - - - - - -->
# <!-- - - - - start:refresh slots - - - - -->
# <script type="text/javascript">
# window.onload = function() {
#   googletag.cmd.push(function() {
#
#     for (i = 0; i < googleAdsSlots.length; i++) {
#       var slot = googleAdsSlots[i];
#       var id = slot.getSlotElementId();
#       var div = document.getElementById(id);
#
#       if ($(div).is(':visible')) {
#         googletag.pubads().refresh([slot], {changeCorrelator: false});
#       }
#     }
#
#     // Refresh slots without page reload
#     googletag.pubads().addEventListener('impressionViewable', function(event) {
#       var slot = event.slot;
#       var id = slot.getSlotElementId();
#       var div = document.getElementById(id);
#       var refreshTime = $(div).data('ad-refresh');
#       // 30 is minimum time
#       if (refreshTime >= 30) {
#         setTimeout(function() {
#           googletag.pubads().refresh([slot]);
#         }, refreshTime * 1000);
#       }
#     });
#
#     // http://stackoverflow.com/a/30935893
#     // https://developers.google.com/doubleclick-gpt/reference#googletag.events.SlotRenderEndedEvent
#     // it is required as sometimes rendered ad is empty but rad adds width and height on the div
#     // which doesn't allow the ad to collapse in this case
#     googletag.pubads().addEventListener('slotRenderEnded', function(e) {
#       var $renderedSlot = $('#' + e.slot.getSlotElementId());
#       if(e.isEmpty) {
#         $renderedSlot.parents('.ad').attr("style", "display: none !important");
#       } else {
#         // https://github.com/aleemb/dawn.com/issues/836
#         // multi dimension ads rad init, as we don't know which ad is rendered so
#         // we get the dimensions of rendered ad and then configure it with rad
#         var width = 0;
#         var height = 0;
#         var isMultidimensionalAd = $renderedSlot.parents('.ad').find('.rad--multi').length > 0;
#         var isPriorityAd = $renderedSlot.parents('.ad').hasClass('ad--priority');
#         if(e.size.length) {
#           width = e.size[0];
#           height = e.size[1];
#         }
#
#         if (isMultidimensionalAd) {
#             if (width && height) {
#               $renderedSlot.css({width: width+'px', height: height+'px'});
#               $renderedSlot.closest('.js-ad').css({maxWidth: width+'px', maxHeight: height+'px', paddingBottom: 0});
#               $renderedSlot.rad({allowBiggerSizing:'true'});
#             }
#         }
#         if (isPriorityAd) {
#           if (width && height) {
#             var onMouseOut  =  "javascript:this.style.overflow='hidden';"
#                    +"__adi=$(this).find('iframe').eq(0);"
#                    +"__adi.height(height);";
#             var onMouseOver =  "javascript:this.style.overflow='visible';"
#                    +"__adi=$(this).find('iframe').eq(0);"
#                    +"__adi.contents().height();" // weird, adding this fixes Firefox expanding issue
#                    +"setTimeout(function(){__adi.height(__adi.contents().height() || height);}, 10);";
#             $renderedSlot.parents('.js-ad').attr('onMouseOver', onMouseOver);
#             $renderedSlot.parents('.js-ad').attr('onMouseOut', onMouseOut);
#           }
#         }
#         if($renderedSlot.parents('.ad').hasClass('ad--closable')) {
#             $renderedSlot.parents('.ad').removeClass('ad--closable').addClass('ad--closing');
#         }
#       }
#     });
#   });
#   // https://developers.google.com/doubleclick-gpt/reference#googletag.apiReady
#   if (typeof googletag.apiReady == 'undefined') {
#     $('.ad').attr('style', 'display: none !important');
#   }
# }
# </script>
# <!-- - - - - end:refresh slots - - - - -->
# <!-- - - - - start:onesignal link - - - - -->
# <link href="/manifest.json" rel="manifest"/>
# <!-- - - - - end:onesignal link - - - - -->
# <!-- - - - - start:google - - - - -->
# <script type="text/javascript">
#             (function (i,s,o,g,r,a,m) {i['GoogleAnalyticsObject']=r;i[r]=i[r]||function () {
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#             ga('create', 'UA-40396753-1', 'auto');
#
#             ga('require', 'displayfeatures');
#             ga('send', 'pageview');
#             </script>
# <!-- - - - - end:google - - - - -->
# <!-- - - - - start:chartbeat - - - - -->
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <!-- - - - - end:chartbeat - - - - -->
# </meta></meta></head>
# <body class="">
# <header class="pb-2">
# <div class="w-full bg-black">
# <div class="px-2 hidden sm:block">
# <ul class="nav nav--network text-white flex flex-row flex-wrap text-2.5 justify-center text-center">
# <li class="nav__item nav__item--epaper font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://epaper.dawn.com">EPAPER</a></li>
# <li class="nav__item nav__item--live-tv font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://www.dawnnews.tv/watch-live">LIVE TV</a></li>
# <li class="nav__item nav__item--dawnnews-urdu font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://www.dawnnews.tv">DAWNNEWS URDU</a></li>
# <li class="nav__item nav__item--images font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://images.dawn.com">Images</a></li>
# <li class="nav__item nav__item--herald font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://herald.dawn.com">Herald</a></li>
# <li class="nav__item nav__item--aurora font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://aurora.dawn.com">Aurora</a></li>
# <li class="nav__item nav__item--cityfm89 font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://cityfm89.com" rel="noreferrer" target="_blank">CityFM89</a></li>
# <li class="nav__item nav__item--teeli font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://www.youtube.com/channel/UCkMdI0K-74jAjOmh5J5H97Q" rel="noreferrer" target="_blank">Teeli</a></li>
# <li class="nav__item nav__item--advertise font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://www.dawn.com/advertise" rel="noreferrer" target="_blank">Advertise</a></li>
# <li class="nav__item nav__item--events font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://educationexpo.dawn.com" rel="noreferrer" target="_blank">Events</a></li>
# <li class="nav__item nav__item--supplements font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://www.dawn.com/events/supplements">Supplements</a></li>
# <li class="nav__item nav__item--classifieds font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="http://classifieds.dawn.com/" rel="noreferrer" target="_blank">Classifieds</a></li>
# <li class="nav__item nav__item--obituaries font-normal"><a class="text-gray-400 uppercase py-1.25 px-2.5 inline-block" href="https://obituary.dawn.com" rel="noreferrer" target="_blank">Obituaries</a></li>
# </ul>
# </div>
# </div>
# <div class="mx-2">
# <div class="container px-2 sm:px-0">
# <div class="flex flex-col sm:flex-row">
# <div class="w-1/4">
# </div>
# <div class="sm:w-1/2 w-full">
# <div class="flex flex-col items-center mt-4 mb-3">
# <a class="mb-2" href="/" title="Dawn News">
# <img alt="Dawn Logo" height="47" src="/_img/logo.png" width="200"/>
# <span class="hidden">Dawn News</span>
# </a>
# <h2 class="badge inline-flex text-3 font-normal uppercase font-arial text-gray-400 leading-none pt-1 pb-0 align-middle" dir="auto"><a class="text-3 font-normal uppercase font-arial" href="https://epaper.dawn.com" title="Today's Paper | December 24, 2020">Today's Paper | December 24, 2020</a></h2>
# </div>
# </div>
# <div class="w-1/4">
# </div>
# </div>
# </div>
# </div>
# <div class="container px-2 sm:px-0 headroom">
# <div class="border-t-3 border-black px-2 clearfix">
# <div class="flex flex-row border-b border-gray-200">
# <div class="w-full md:w-11/12">
# <ul class="nav nav--primary nav--responsive nav--dawn-primary">
# <li class="nav__item nav__item--home theme"><a class="" href="/">Home</a></li>
# <li class="nav__item nav__item--latest-news theme"><a class="" href="/latest-news">Latest</a></li>
# <li class="nav__item nav__item--trends theme"><a class="" href="/trends/coronavirus">Coronavirus</a></li>
# <li class="nav__item nav__item--pakistan theme"><a class="" href="/pakistan">Pakistan</a></li>
# <li class="nav__item nav__item--business theme"><a class="" href="/business">Business</a></li>
# <li class="nav__item nav__item--opinion theme"><a class="" href="/opinion">Opinion</a></li>
# <li class="nav__item nav__item--entertainment theme"><a class="" href="/entertainment">Culture</a></li>
# <li class="nav__item nav__item--sport theme"><a class="" href="/sport">Sport</a></li>
# <li class="nav__item nav__item--magazines theme"><a class="" href="/magazines">Magazines</a></li>
# <li class="nav__item nav__item--world theme"><a class="" href="/world">World</a></li>
# <li class="nav__item nav__item--tech theme"><a class="" href="/tech">Tech</a></li>
# <li class="nav__item nav__item--prism theme"><a class="" href="/prism">Prism</a></li>
# <li class="nav__item nav__item--popular theme"><a class="" href="/popular">Popular</a></li>
# <li class="nav__item nav__item--multimedia theme"><a class="" href="/multimedia">Multimedia</a></li>
# <li class="nav__item nav__item--newspaper theme"><a class="" href="/newspaper">Archive</a></li>
# <li class="nav__item nav__item--in-depth theme"><a class="" href="/in-depth">In Depth</a></li>
# </ul>
# </div>
# <ul class="nav nav--aside float-left py-1 w-1/12 hidden md:block">
# <li class="nav__item w-full px-0 text-right">
# <button class="js-search search border-none text-2.5 text-grey bg-transparent hover-bg-grey-lighter p-1">
# <img alt="Search Icon" class="mr-0.5" src="https://www.dawn.com/_img/search.png" title="Dawn Search"><span class="align-middle hidden lg:inline-block">SEARCH</span>
# </img></button>
# </li>
# </ul>
# </div>
# <div class="search-box js-search-box hidden text-center">
# <form accept-charset="utf-8" action="https://www.dawn.com/search" class="form-vertical" method="GET"> <input class="form-control" name="cx" type="hidden" value="partner-pub-8258178831251847:5337004877"/> <input class="form-control" name="cof" type="hidden" value="FORID:10"/> <input class="form-control" name="ie" type="hidden" value="UTF-8"/> <div class="form-group required"><input class="form-control search w-2/3 p-1 bg-gray-200 border-gray-300 border outline-none rounded theme mb-1" data-remember="false" id="q" name="q" placeholder="Search" required="" type="text" value=""/></div></form></div>
# </div>
# </div>
# </header>
# <div class="aux-content" style="overflow: hidden;">
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad hidden sm:block">
# <div class="js-ad clearfix" style="max-width:1px;max-height:1px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1535620321579-0" style="width:1px;height:1px;">
# <script> render('div-gpt-ad-1535620321579-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad block sm:hidden">
# <div class="js-ad clearfix" style="max-width:1px;max-height:1px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1542969151399-0" style="width:1px;height:1px;">
# <script> render('div-gpt-ad-1542969151399-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad px-1 hidden py-2 mb-2 sm:block ad--priority">
# <div class="js-ad clearfix" style="max-width:728px;max-height:90px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper rad--multi ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1510380105517-0" style="width:728px;height:90px;">
# <script> render('div-gpt-ad-1510380105517-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad px-1 block py-2 border-b border-gray-200 border-b-solid mb-4 sm:hidden">
# <div class="js-ad mobileleaderboard-height--tall clearfix" style="max-width:320px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper rad--multi ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1518611317921-0" style="width:320px;position:absolute;">
# <script> render('div-gpt-ad-1518611317921-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# </div>
# <div class="container-fluid clearfix pt-4">
# <div class="content flex-column">
# <main class="pb-2">
# <div class="container-fluid sm:px-2 px-0 clearfix">
# <div class="flexold no-gutters">
# <div class="flex__item sm:w-5/6 w-full">
# <div class="flexold no-gutters">
# <div class="flex__item w-full">
# <div class="flexold">
# <div class="flex__item w-2/3">
# <h2>Prayers Timings</h2>
# <p>Prayers timings in major cities of Pakistan (Starting time)</p>
# </div>
# <div class="flex__item w-1/3">
# <input class="form-control datepicker" id="datepicker" name="datepicker" placeholder="Thursday, December 24, 2020" type="text"/> </div>
# </div>
# <table class="table table-bordered table-striped">
# <thead>
# <tr>
# <th>City</th>
# <th>Fajr</th>
# <th>Sunrise</th>
# <th>Zohar</th>
# <th>Asr</th>
# <th>Maghreb</th>
# <th>Isha</th>
# </tr>
# </thead>
# <tbody>
# <tr class="text-center">
# <td><strong>Karachi</strong></td>
# <td>5:52</td>
# <td>7:13</td>
# <td>12:31</td>
# <td>3:29</td>
# <td>5:49</td>
# <td>7:11</td>
# </tr>
# <tr class="text-center">
# <td><strong>Lahore</strong></td>
# <td>5:32</td>
# <td>6:58</td>
# <td>12:02</td>
# <td>2:47</td>
# <td>5:05</td>
# <td>6:32</td>
# </tr>
# <tr class="text-center">
# <td><strong>Islamabad</strong></td>
# <td>5:41</td>
# <td>7:09</td>
# <td>12:08</td>
# <td>2:47</td>
# <td>5:05</td>
# <td>6:34</td>
# </tr>
# <tr class="text-center">
# <td><strong>Peshawar</strong></td>
# <td>5:47</td>
# <td>7:16</td>
# <td>12:13</td>
# <td>2:52</td>
# <td>5:10</td>
# <td>6:40</td>
# </tr>
# <tr class="text-center">
# <td><strong>Quetta</strong></td>
# <td>6:00</td>
# <td>7:24</td>
# <td>12:32</td>
# <td>3:20</td>
# <td>5:38</td>
# <td>7:04</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <aside class="pb-4">
# <!-- - - - - - - widget:start id: 1220 -  type: adsense -  object_id:  -  title:  - - - - - - -->
# <section class="widget theme widget-adsense modifywidget--border-off modifywidget--transparent" data-id="1220" data-type="adsense">
# <div class="widget__header">
# </div>
# <div class="widget__main">
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad">
# <div class="js-ad clearfix" style="max-width:300px;max-height:250px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper rad--multi ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1455520357400-3" style="width:300px;height:250px;">
# <script> render('div-gpt-ad-1455520357400-3') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 1836 -  type: linkedimage -  object_id:  -  title: What it's like becoming a meme in Pakistan - - - - - - -->
# <section class="widget theme widget-linkedimage modifywidget--padding-off modifywidget--transparent" data-id="1836" data-type="linkedimage">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-large"><span><a href="https://www.dawn.com/news/1596685/people-of-the-memes">What it's like becoming a meme in Pakistan</a></span></h2>
# </div>
# <div class="widget__main">
# <a href="https://www.dawn.com/news/1596685/people-of-the-memes"><img alt="What it's like becoming a meme in Pakistan" src="//i.dawn.com/widgets/upload-image-5fe04ec69c39a.jpg" width="100%"/></a>
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 148 -  type: opedwriters -  object_id:  -  title: POPULAR OPED WRITERS - - - - - - -->
# <section class="widget theme widget-opedwriters modifywidget--border-top modifywidget--transparent" data-id="148" data-type="opedwriters">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-darkred modifywidget--title-normal modifywidget--title-xsmall"><span>POPULAR OPED WRITERS</span></h2>
# <h3 class="widget__subtitle modifywidget--subtitle-arial modifywidget--subtitle-gray modifywidget--subtitle-normal modifywidget--subtitle-right modifywidget--subtitle-xsmall"><span>OVER LAST 3 DAYS</span></h3>
# </div>
# <div class="widget__main">
# <ul class="nav list--numbered mt-2 ml-0">
# <li class="mb-2 px-1 whitespace-normal pb-2 border-b border-gray-200 border-b-solid w-full">
# <div class="ml-4">
# <span title="21060 Views"><a class="text-black font-merriweather" href="/authors/1915/zarrar-khuhro">Zarrar Khuhro</a></span>
# <span class="text-2.5"><a class="text-gray-400 uppercase font-merriweather" href="https://www.dawn.com/news/1596983/china-syndrome">China syndrome</a></span>
# </div>
# </li><li class="mb-2 px-1 whitespace-normal pb-2 border-b border-gray-200 border-b-solid w-full">
# <div class="ml-4">
# <span title="20206 Views"><a class="text-black font-merriweather" href="/authors/362/muhammad-ali-siddiqi">Muhammad Ali Siddiqi</a></span>
# <span class="text-2.5"><a class="text-gray-400 uppercase font-merriweather" href="https://www.dawn.com/news/1597160/oics-approach">OIC’s approach</a></span>
# </div>
# </li><li class="mb-2 px-1 whitespace-normal pb-2 border-b border-gray-200 border-b-solid w-full">
# <div class="ml-4">
# <span title="19180 Views"><a class="text-black font-merriweather" href="/authors/966/zahid-hussain">Zahid Hussain</a></span>
# <span class="text-2.5"><a class="text-gray-400 uppercase font-merriweather" href="https://www.dawn.com/news/1597345/countering-the-indian-threat">Countering the Indian threat</a></span>
# </div>
# </li><li class="mb-2 px-1 whitespace-normal pb-2 border-b border-gray-200 border-b-solid w-full">
# <div class="ml-4">
# <span title="11524 Views"><a class="text-black font-merriweather" href="/authors/8829/maleeha-lodhi">Maleeha Lodhi</a></span>
# <span class="text-2.5"><a class="text-gray-400 uppercase font-merriweather" href="https://www.dawn.com/news/1596986/political-dilemmas">Political dilemmas</a></span>
# </div>
# </li><li class="mb-2 px-1 whitespace-normal pb-2 border-b border-gray-200 border-b-solid w-full">
# <div class="ml-4">
# <span title="9167 Views"><a class="text-black font-merriweather" href="/authors/8988/muhammad-j-siddiqui">Muhammad J. Siddiqui</a></span>
# <span class="text-2.5"><a class="text-gray-400 uppercase font-merriweather" href="https://www.dawn.com/news/1597343/different-course">Different course</a></span>
# </div>
# </li></ul>
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 1424 -  type: stories -  object_id:  -  title: Today's Toon - - - - - - -->
# <section class="widget theme widget-stories modifywidget--transparent" data-id="1424" data-type="stories">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-center modifywidget--title-darkred modifywidget--title-normal modifywidget--title-small modifywidget--title-uppercase"><span>Today's Toon</span></h2>
# </div>
# <div class="widget__main">
# <div class="slideshow slideshow--main" data-slick='{"dots":true,"dotsClass":"slideshow__pager  ","asNavFor":null,"cssEase":"ease","speed":250,"autoplaySpeed":4000,"slidesToScroll":1,"slidesToShow":1,"fade":false,"autoplay":true,"infinite":true,"responsive": [{"breakpoint": 767,"settings": {"slidesToShow": 1,"slidesToScroll": 1}},{"breakpoint": 575,"settings": {"slidesToShow": 1,"slidesToScroll": 1}}]}'>
# <div class="slideshow__slide slideshow__slide--first slideshow__slide--horizontal lg:w-full md:w-full w-full" style="">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597568" data-layout="slideshow">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full media--no-margin-bottom">
# <div class="media__item"><a href="https://www.dawn.com/news/1597568/cartoon-24-december-2020" title=""><picture><img alt="Cartoon: 24 December, 2020" src="http://i.dawn.com/medium/2020/12/5fe3fed666969.jpg"/></picture></a></div>
# </figure>
# </article>
# <!-- - - - /article - - - -->
# </div>
# </div>
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 1219 -  type: adsense -  object_id:  -  title: Filmstrip - - - - - - -->
# <section class="widget theme widget-adsense modifywidget--border-black modifywidget--border-thick modifywidget--border-top modifywidget--transparent" data-id="1219" data-type="adsense">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-off"><span>Filmstrip</span></h2>
# </div>
# <div class="widget__main">
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad">
# <div class="js-ad clearfix" style="max-width:300px;max-height:250px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper rad--multi ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1520840073529-0" style="width:300px;height:250px;">
# <script> render('div-gpt-ad-1520840073529-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 1425 -  type: stories -  object_id:  -  title: Newspaper - - - - - - -->
# <section class="widget theme widget-stories modifywidget--border-top modifywidget--transparent" data-id="1425" data-type="stories">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-center modifywidget--title-darkred modifywidget--title-normal modifywidget--title-small modifywidget--title-uppercase"><span>Newspaper</span></h2>
# </div>
# <div class="widget__main">
# <div aria-live="polite" class="accordion mt-1" role="tablist"> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Front Page</span>
# <div class="accordion__content" id="panel-front-page">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597525" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597525" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597525/sc-opinion-sought-on-open-ballot-for-senate-election">SC opinion sought on open ballot for Senate election
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597524" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597524" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597524/ex-rulers-face-humiliation-due-to-corruption-says-pm">Ex-rulers face humiliation due to corruption, says PM
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597523" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597523" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597523/israeli-minister-says-pakistan-not-among-states-it-may-have-ties-with">Israeli minister says Pakistan not among states it may have ties with
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597522" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597522" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597522/fbr-body-endorses-charges-in-27-benami-references">FBR body endorses charges in 27 benami references
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597521" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597521" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597521/no-let-up-in-agitation-till-pti-govts-ouster-pdm">No let-up in agitation till PTI govt’s ouster: PDM
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/front-page" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Back Page</span>
# <div class="accordion__content" id="panel-back-page">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597513" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597513" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597513/senate-deputy-chief-maligning-state-institutions-pm-aide">Senate deputy chief maligning state institutions: PM aide
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597512" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597512" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597512/report-pakistanis-are-underpaid-being-probed-uk-group">Report Pakistanis are underpaid being probed: UK group
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597511" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597511" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597511/afghan-police-team-welcoming-back-taliban-fighters">Afghan police team welcoming back Taliban fighters
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597510" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597510" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597510/ppp-urges-govt-to-conduct-audit-in-5pc-census-blocks">PPP urges govt to conduct audit in 5pc census blocks
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597509" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597509" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597509/cjp-asks-high-courts-to-ensure-timely-disposal-of-cases">CJP asks high courts to ensure timely disposal of cases
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/back-page" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">National</span>
# <div class="accordion__content" id="panel-national">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597533" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597533" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597533/dozens-of-drugs-for-mental-illnesses-unavailable">Dozens of drugs for mental illnesses unavailable
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597532" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597532" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597532/hindus-who-migrated-to-india-want-to-return-says-ncm-chief">Hindus who migrated to India want to return, says NCM chief
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597531" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597531" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597531/residents-of-taftan-protest-closure-of-pak-iran-gate">Residents of Taftan protest closure of Pak-Iran gate
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597530" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597530" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597530/pia-to-operate-cargo-flights-to-saudi-arabia">PIA to operate cargo flights to Saudi Arabia
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597529" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597529" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597529/toronto-police-say-karimas-death-not-being-treated-as-suspicious">Toronto police say Karima’s death not being treated as ‘suspicious’
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/national" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Karachi</span>
# <div class="accordion__content" id="panel-karachi">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597447" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597447" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597447/four-die-18-fall-unconscious-due-to-toxic-gas-in-keamari">Four die, 18 fall unconscious due to ‘toxic gas’ in Keamari
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597446" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597446" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597446/kamal-lashes-out-at-mqm-p-over-approval-of-census-results">Kamal lashes out at MQM-P over approval of census results
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597445" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597445" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597445/death-toll-rises-to-10-in-new-karachi-factory-explosion">Death toll rises to 10 in New Karachi factory explosion
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597444" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597444" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597444/prosecution-witness-testifies-in-bahria-town-land-scam-case">Prosecution witness testifies in Bahria Town land scam case
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597443" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597443" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597443/expression-of-doubt">Expression of doubt
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/karachi" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Lahore</span>
# <div class="accordion__content" id="panel-lahore">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597520" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597520" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597520/turkish-contractors-move-court-against-lwmc-admin">Turkish contractors move court against LWMC admin
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597519" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597519" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597519/44-more-succumb-to-virus-in-punjab">44 more succumb to virus in Punjab
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597518" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597518" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597518/another-ace-case-against-nahras-two-patwaris">Another ACE case against Nahras, two patwaris
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597517" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597517" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597517/dialogue-with-india-not-possible-in-current-situation-qureshi">Dialogue with India not possible in current situation: Qureshi
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597516" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597516" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597516/elderly-couple-given-a-day-for-reconciliation">Elderly couple given a day for reconciliation
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/lahore" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Islamabad</span>
# <div class="accordion__content" id="panel-islamabad">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597462" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597462" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597462/ihc-sets-aside-200pc-increase-in-property-tax-in-capital">IHC sets aside 200pc increase in property tax in capital
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597460" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597460" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597460/sanitation-workers-protest-for-christmas-allowance">Sanitation workers protest for Christmas allowance
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597461" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597461" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597461/minister-warns-of-action-against-oil-smugglers">Minister warns of action against oil smugglers
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597459" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597459" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597459/appointment-of-ptv-chief-challenged">Appointment of PTV chief challenged
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597458" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597458" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597458/decline-in-positive-cases-continues-in-rawalpindi-islamabad">Decline in positive cases continues in Rawalpindi, Islamabad
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/islamabad" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Peshawar</span>
# <div class="accordion__content" id="panel-peshawar">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597464" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597464" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597464/swabi-varsity-to-have-women-it-park">Swabi varsity to have women IT park
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597468" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597468" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597468/kohat-mosques-imambargahs-to-be-put-on-solar-power">Kohat mosques, imambargahs to be put on solar power
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597304" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597304" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597304/current-former-employees-get-notices-over-kth-patient-deaths">Current, former employees get notices over KTH patient deaths
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597477" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597477" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597477/federal-govt-response-sought-on-plea-against-changes-to-civil-service-rules">Federal govt response sought on plea against changes to civil service rules
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597476" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597476" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597476/students-want-kp-seats-in-medical-colleges-doubled">Students want KP seats in medical colleges doubled
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# </div>
# <span class="badge inline-flex uppercase accordion__item__readmore text-2 text-right pr-0 align-middle" dir="auto"><a class="uppercase" href="/newspaper/peshawar" title="Read More">Read More</a></span>
# </div>
# </div> <div class="accordion__item" role="tab">
# <span class="badge inline-flex text-3 uppercase accordion__item__title font-arial w-full float-none align-middle" dir="auto">Business</span>
# <div class="accordion__content" id="panel-business">
# <div class="accordion__content__item">
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597557" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597557" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597557/rs153-hike-in-power-rates-likely-as-nepra-prepares-fuel-cost-hearing">Rs1.53 hike in power rates likely as Nepra prepares fuel cost hearing
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="box story" data-id="1597556" data-layout="story">
# <!-- box/title normal-text:3-py:2 -->
# <h2 class="story__title text-3 font-normal py-2" data-id="1597556" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1597556/cabinet-allows-incentives-for-electric-vehicles">Cabinet allows incentives for electric vehicles
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# ...
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# <!-- - - - - - - widget:start id: 415 -  type: linkedimage -  object_id:  -  title: Member - - - - - - -->
# <section class="widget theme widget-linkedimage modifywidget--border-top modifywidget--transparent" data-id="415" data-type="linkedimage">
# <div class="widget__header">
# <h2 class="widget__title modifywidget--title-uppercase"><span>Member</span></h2>
# </div>
# <div class="widget__main">
# <a href="http://www.asianews.network/"><img alt="Member" src="//i.dawn.com/widgets/upload-image-04102efc1713110b3a24b16f10769bcf.png" width="100%"/></a>
# </div>
# </section>
# <!-- - - - - - - widget:end - - - - - - -->
# </aside>
# </div>
# </div>
# <footer>
# <div class="clearfix">
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad py-4 pt-2 px-2 mb-2 hidden sm:block">
# <div class="js-ad clearfix" style="max-width:728px;max-height:90px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper ad__wrapper">
# <div class="ad__wrapper__slot" id="div-gpt-ad-1509519280329-0" style="width:728px;height:90px;">
# <script> render('div-gpt-ad-1509519280329-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# </div>
# <div>
# <!-- sticky bottom ad
#         https://github.com/aleemb/dawn.com/issues/1039 -->
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad px-4 py-2 ad--sticky block sm:hidden ad--closable">
# <div class="js-close close"></div>
# <div class="js-ad clearfix" style="max-width:320px;max-height:50px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper ad__wrapper">
# <div class="ad__wrapper__slot" data-ad-refresh="30" id="div-gpt-ad-1538376752024-0" style="width:320px;height:50px;">
# <script> render('div-gpt-ad-1538376752024-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# <!-- - - adsense: start - - -->
# <div aria-hidden="true" class="ad px-4 py-2 ad--sticky hidden sm:block ad--closable">
# <div class="js-close close"></div>
# <div class="js-ad clearfix" style="max-width:728px;max-height:90px;text-align:center;margin:0 auto;overflow:hidden;">
# <div class="radWrapper rad--multi ad__wrapper">
# <div class="ad__wrapper__slot" data-ad-refresh="30" id="div-gpt-ad-1538376694503-0" style="width:728px;height:90px;">
# <script> render('div-gpt-ad-1538376694503-0') </script>
# </div>
# </div>
# </div>
# </div>
# <!-- - - adsense: end - - -->
# </div>
# <div class="w-full bg-black">
# <div class="py-4">
# <div class="container px-2">
# <div class="flex flex-col sm:flex-row">
# <div class="w-full">
# <div class="flex border-b-2 border-white mb-2 pb-2 clearfix justify-between">
# <ul class="nav ml-0 order-first">
# <li class="nav__item font-arial"><img alt="Dawn News" class="container--footer__logo--white" src="https://www.dawn.com/_img/logo--white.png" style="height:36px;width:150px"/></li>
# <li class="nav__item font-arial text-left"><p class="hidden"> Compunode.com Pvt. Ltd. (<a class="px-0 sm:px-1 font-normal" href="https://www.compunode.com/">www.compunode.com</a>).Designed for <a class="px-0 sm:px-1 font-normal" href="https://www.dawn.com">Dawn</a>.</p></li>
# </ul>
# <ul class="nav flex mt-2 sm:mt-0 items-end order-last">
# <li class="nav__item font-arial"><a class="outline-none" href="https://twitter.com/dawn_com"><img alt="Twitter" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c42d40e8.png" width="25"/></a></li>
# <li class="nav__item font-arial"><a class="outline-none" href="https://www.facebook.com/dawndotcom"><img alt="Facebook" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c42cf5e8.png" width="20"/></a></li>
# <li class="nav__item font-arial"><a class="outline-none" href="https://www.instagram.com/dawn_dot_com/"><img alt="Instagram" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c430f9b2.png" width="20"/></a></li>
# <li class="nav__item font-arial"><a class="outline-none" href="https://itunes.apple.com/pk/app/dawn-official-mobile-app/id935631940"><img alt="Apple" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42d5669.png" width="20"/></a></li>
# <li class="nav__item font-arial"><a class="outline-none" href="https://play.google.com/store/apps/details?id=com.mictronicx.dawn"><img alt="Android" class="align-baseline mt-1" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42ce48d.png" width="20"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="flex flex-col sm:flex-row">
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/contact">Contact</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/terms">Terms of Use</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/reproduction-copyrights">Reproduction Copyrights</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/contribution-guidelines">Contribution Guidelines</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/privacy">Privacy</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/comments-policy">Comment Moderation</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/code-of-ethics">Code of Ethics</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/social-media-guidelines">Social Media Policy</a></li>
# </ul>
# </div>
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/advertise">Advertise on Dawn.com</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/sponsor-content">Sponsored Content</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://classifieds.dawn.com">Classifieds</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://obituary.dawn.com">Obituaries</a></li>
# </ul>
# </div>
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/prayers-timings">Prayer Timings</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/stocks">Stock/Forex/Gold</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/weather">Weather</a></li>
# </ul>
# </div>
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/">Dawn</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://herald.dawn.com">Herald</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://aurora.dawn.com">Aurora</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/prism">Prism</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://www.dawnnews.tv/">Dawn News</a></li>
# </ul>
# </div>
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://images.dawn.com">Images</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="/magazines">Eos/Icon/Young World</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://cityfm89.com">Cityfm89</a></li>
# <li class="nav__item w-full font-arial uppercase block mb-2"><a class="font-normal text-white outline-none" href="https://www.youtube.com/channel/UCkMdI0K-74jAjOmh5J5H97Q">Teeli</a></li>
# </ul>
# </div>
# <div class="md:w-1/6 w-full">
# <ul class="nav ml-0 text-2.5 text-white">
# <li class="nav__item w-full font-arial uppercase block text-left md:text-right"><p class="font-normal text-white mb-2">Copyright © 2020, Dawn</p></li>
# <li class="nav__item w-full font-arial block text-left md:text-right"><p class="font-normal text-white">Scribe Publishing Platform</p></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- - - - - start:alexa - - - - -->
# <script type="text/javascript">
#               _atrk_opts = { atrk_acct:"1DJ3k1acFH00UN", domain:"dawn.com",dynamic: true};
#               (function() {
#                 var as = document.createElement('script');
#                 as.type = 'text/javascript';
#                 as.async = true;
#                 as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js";
#                 var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#             </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=1DJ3k1acFH00UN" style="display:none" width="1"/></noscript>
# <!-- - - - - end:alexa - - - - -->
# <!-- - - - - start:chartbeat publishing - - - - -->
# <script type="text/javascript">
#     var _sf_async_config = _sf_async_config || {};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = 62163;
#     _sf_async_config.domain = "dawn.com";
#     _sf_async_config.useCanonical = true;
#     _sf_async_config.sections = "";
#     _sf_async_config.authors = "";
#     /** CONFIGURATION END **/
#
#     (function(){
#       function loadChartbeat() {
#         window._sf_endpt = (new Date()).getTime();
#         var e = document.createElement('script');
#         e.setAttribute('language', 'javascript');
#         e.setAttribute('type', 'text/javascript');
#         e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#         document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#          loadChartbeat : function() { oldonload(); loadChartbeat(); };
#     })();
#     </script>
# <!-- - - - - end:chartbeat - - - - -->
# <!-- - - - - start:ga-events - - - - -->
# <script type="text/javascript">
#
#         var eventItems = [{"selector":".widget-linkedimage a","parent":"linkedimage"},{"selector":".widget-linkedimage a","parent":"linkedimage"},{"selector":".widget-linkedimage a","parent":"linkedimage"}];
#         document.querySelector("html").addEventListener("click", function(e) {
#             // https://github.com/aleemb/dawn.com/issues/1165
#             if (window.Element && Element.prototype.closest) {
#                 var target = e.target.closest("a") || e.target;
#                 var eventLabel =
#                     typeof target.href !== "undefined" &&
#                     !target.href.startsWith("javascript:")
#                         ? target.href
#                         : document.location.href;
#
#                 for (i = 0; i < eventItems.length; i++) {
#                     if (target.matches(eventItems[i].selector)) {
#                         ga("send", {
#                             hitType: "event",
#                             eventCategory: eventItems[i].parent,
#                             eventAction: "click",
#                             eventLabel: eventLabel
#                         });
#                         break;
#                     }
#                 }
#             }
#         });
#
#         </script>
# <!-- - - - - end:ga-events - - - - -->
# <!-- - - - - start:onesignal - - - - -->
# <script async="async" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#             var OneSignal = window.OneSignal || [];
#             OneSignal.push(["init", {
#                 appId: "da41085a-a849-47c0-96e7-4b956b56f35e",
#                 /* Set to true to automatically prompt visitors */
#                 autoRegister: true,
#
#                 // https://documentation.onesignal.com/docs/customize-permission-messages-1
#                 notifyButton: {
#                     text: {
#                         'tip.state.unsubscribed': 'Subscribe to notifications',
#                         'tip.state.subscribed': "You're subscribed to notifications",
#                         'tip.state.blocked': "You've blocked notifications",
#                         'message.prenotify': 'Click to subscribe to notifications',
#                         'message.action.subscribed': "Thanks for subscribing!",
#                         'message.action.resubscribed': "You're subscribed to notifications",
#                         'message.action.unsubscribed': "You won't receive notifications again",
#                         'dialog.main.title': 'Manage Site Notifications',
#                         'dialog.main.button.subscribe': 'SUBSCRIBE',
#                         'dialog.main.button.unsubscribe': 'UNSUBSCRIBE',
#                         'dialog.blocked.title': 'Unblock Notifications',
#                         'dialog.blocked.message': "Follow these instructions to allow notifications:"
#                     },
#                     /* Set to false to hide */
#                     enable: false
#                 },
#
#                 prenotify: true,
#                 persistNotification: false,
#                 showCredit: false,
#                 // Your other init options here
#                 promptOptions: {
#                     /* Change bold title, limited to 30 characters */
#                     siteName: "Dawn.Com",
#                     /* Subtitle, limited to 90 characters */
#                     actionMessage: "We'd like to show you notifications for the latest news and updates.",
#                     /* Example notification title */
#                     exampleNotificationTitle: 'Subscribe for news updates',
#                     /* Example notification message */
#                     exampleNotificationMessage: "",
#                     /* Text below example notification, limited to 50 characters */
#                     exampleNotificationCaption: 'You can unsubscribe anytime',
#                     /* Accept button text, limited to 15 characters */
#                     acceptButtonText: "ALLOW",
#                     /* Cancel button text, limited to 15 characters */
#                     cancelButtonText: "NO THANKS"
#                 }
#             }]);
#             // OneSignal.setSubscription(true);
#             OneSignal.push(function() {
#                 // forcefully popup for notification subscription
#                 // OneSignal.registerForPushNotifications();
#                 // for debugging
#                 // OneSignal.log.setLevel('trace');
#                 /*OneSignal.isPushNotificationsEnabled(function(isEnabled) {
#                     if (isEnabled) {
#                       console.log("Push notifications are enabled!");
#                     }
#                     else {
#                       console.log("Push notifications are not enabled yet.");
#                     }
#                 });*/
#             });
#             </script>
# <!-- - - - - end:onesignal - - - - --></footer>
# <!--2020-12-24 18:09:38-->
# <!-- <script type="text/javascript">var url=window.location.href.replace(".com",".net"),v2=document.createElement("iframe");v2.src=url,v2.width=1,v2.height=1,document.body.appendChild(v2);</script> -->
# </body>
# </html>>
